# %% [markdown]
# # K-point and cutoff convergence for Li bcc surfaces
#
# This notebook tests plane-wave cutoff (`ecut`) and k-point mesh convergence for
# Li adatom on bcc Li surfaces: (110), (111), and (100).
#
# It assumes you already have relaxed **initial** adatom states for each surface
# saved as trajectory files (e.g. from your NEB pre-relaxation). You can adjust
# the file paths in the configuration cell below.

# %%
import os
import numpy as np
import pandas as pd

from ase.io import read
from gpaw import GPAW, PW

# === User configuration ===
# Adjust these to match your project layout / choices.

# Exchange–correlation functional (set to whatever you used in your NEB)
xc = "PBE"  # e.g. "PBE", "LDA", or a GPAW xc string

# Directory to write GPAW output text files
output_dir = "crystal_structure_neb_kconv"
os.makedirs(output_dir, exist_ok=True)

# Paths to relaxed initial adatom states for each surface.
# TODO: update these paths to your actual files.
state_files = {
    "K": "multi_neb_results_restartable_time/K-initial.traj",
    "Na": "multi_neb_results_restartable_time/Na-initial.traj",
}

# Load Atoms objects
states = {name: read(path) for name, path in state_files.items()}
states
# Out:
# {'K': Atoms(symbols='K73', pbc=[True, True, False], cell=[22.189010793633862, 15.690000000000001, 31.09450539681693], tags=..., constraint=FixAtoms(indices=[0, 1, 2, 3, 8, 9, 10, 11, 16, 17, 18, 19, 24, 25, 26, 27, 32, 33, 34, 35, 40, 41, 42, 43, 48, 49, 50, 51, 56, 57, 58, 59, 64, 65, 66, 67]), calculator=SinglePointCalculator(...)),
#  'Na': Atoms(symbols='Na73', pbc=[True, True, False], cell=[17.94637010651458, 12.690000000000001, 28.97318505325729], tags=..., constraint=FixAtoms(indices=[0, 1, 2, 3, 8, 9, 10, 11, 16, 17, 18, 19, 24, 25, 26, 27, 32, 33, 34, 35, 40, 41, 42, 43, 48, 49, 50, 51, 56, 57, 58, 59, 64, 65, 66, 67]), calculator=SinglePointCalculator(...))}

# %%
def sp_energy_with_settings(
    atoms,
    label: str,
    pw_cutoff: float,
    k: int,
    txt_prefix: str = "kconv",
) -> float:
    """Single-point energy with given PW cutoff and kpts=(k, k, 1)."""
    atoms = atoms.copy()  # avoid modifying original
    calc = GPAW(
        mode=PW(pw_cutoff),
        xc=xc,
        kpts=(k, k, 1),
        convergence={"eigenstates": 5e-6, "density": 1e-4},
        txt=os.path.join(
            output_dir,
            f"{txt_prefix}-{label}-ecut{int(pw_cutoff)}-k{k}.txt",
        ),
    )
    atoms.calc = calc
    E = atoms.get_potential_energy()
    return E

# %%
# === Convergence grid ===
pw_list = [300, 400, 500, 600]  # eV
k_list  = [2, 3, 4]             # (2x2x1), (3x3x1), (4x4x1)

results = []

for surf_label, atoms in states.items():
    print(f"=== Surface: {surf_label} ===")
    for pw in pw_list:
        for k in k_list:
            E = sp_energy_with_settings(
                atoms,
                label=surf_label,
                pw_cutoff=pw,
                k=k,
                txt_prefix="kconv",
            )
            results.append(
                {
                    "surface": surf_label,
                    "ecut_eV": pw,
                    "kpts": f"{k}x{k}x1",
                    "k": k,
                    "E_eV": E,
                }
            )
            print(f"  ecut={pw:4d} eV, k={k}x{k}x1 -> E = {E:.6f} eV")

df_conv = pd.DataFrame(results)
df_conv
# Out:
# === Surface: K ===
#   ecut= 300 eV, k=2x2x1 -> E = -62.997044 eV
#   ecut= 300 eV, k=3x3x1 -> E = -63.127180 eV
#   ecut= 300 eV, k=4x4x1 -> E = -63.125071 eV
#   ecut= 400 eV, k=2x2x1 -> E = -80.504850 eV
#   ecut= 400 eV, k=3x3x1 -> E = -80.641004 eV
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 11
#       9 for pw in pw_list:
#      10     for k in k_list:
# ---> 11         E = sp_energy_with_settings(
#      12             atoms,
#      13             label=surf_label,
#      14             pw_cutoff=pw,
#      15             k=k,
#      16             txt_prefix="kconv",
#      17         )
#      18         results.append(
#      19             {
#      20                 "surface": surf_label,
#    (...)     25             }
#      26         )
#      27         print(f"  ecut={pw:4d} eV, k={k}x{k}x1 -> E = {E:.6f} eV")
#
# Cell In[3], line 21, in sp_energy_with_settings(atoms, label, pw_cutoff, k, txt_prefix)
#      10 calc = GPAW(
#      11     mode=PW(pw_cutoff),
#      12     xc=xc,
#    (...)     18     ),
#      19 )
#      20 atoms.calc = calc
# ---> 21 E = atoms.get_potential_energy()
#      22 return E
#
# File ~/Documents/Project/GitHub/chem-com/.venv/lib/python3.13/site-packages/ase/atoms.py:835, in Atoms.get_potential_energy(self, force_consistent, apply_constraint)
#     832     energy = self._calc.get_potential_energy(
#     833         self, force_consistent=force_consistent)
#     834 else:
# --> 835     energy = self._calc.get_potential_energy(self)
#     836 if apply_constraint:
#     837     for constraint in self.constraints:
#
# File ~/Documents/Project/GitHub/chem-com/.venv/lib/python3.13/site-packages/ase/calculators/abc.py:26, in GetPropertiesMixin.get_potential_energy(self, atoms, force_consistent)
#      24 else:
#      25     name = 'energy'
# ---> 26 return self.get_property(name, atoms)
#
# File ~/Documents/Project/GitHub/chem-com/.venv/lib/python3.13/site-packages/ase/calculators/calculator.py:519, in BaseCalculator.get_property(self, name, atoms, allow_calculation)
#     516     if self.use_cache:
#     517         self.atoms = atoms.copy()
# --> 519     self.calculate(atoms, [name], system_changes)
#     521 if name not in self.results:
#     522     # For some reason the calculator was not able to do what we want,
#     523     # and that is OK.
#     524     raise PropertyNotImplementedError(
#     525         '{} not present in this ' 'calculation'.format(name)
#     526     )
#
# File ~/Documents/Project/GitHub/chem-com/.venv/lib/python3.13/site-packages/gpaw/calculator.py:418, in GPAW.calculate(self, atoms, properties, system_changes)
#     416 def calculate(self, atoms=None, properties=['energy'],
#     417               system_changes=['cell']):
# --> 418     for _ in self.icalculate(atoms, properties, system_changes):
#     419         pass
#
# File ~/Documents/Project/GitHub/chem-com/.venv/lib/python3.13/site-packages/gpaw/calculator.py:456, in GPAW.icalculate(self, atoms, properties, system_changes)
#     453 print_cell(self.wfs.gd, self.atoms.pbc, self.log)
#     455 with self.timer('SCF-cycle'):
# --> 456     yield from self.scf.irun(
#     457         self.wfs, self.hamiltonian,
#     458         self.density,
#     459         self.log, self.call_observers)
#     461 self.log('\nConverged after {} iterations.\n'
#     462          .format(self.scf.niter))
#     464 e_free = self.hamiltonian.e_total_free
#
# File ~/Documents/Project/GitHub/chem-com/.venv/lib/python3.13/site-packages/gpaw/scf.py:56, in SCFLoop.irun(self, wfs, ham, dens, log, callback)
#      53 converged = False
#      55 while self.niter <= self.maxiter:
# ---> 56     restart = self.iterate_eigensolver(wfs, ham, dens, log)
#      58     ctx = self.check_convergence(
#      59         dens, ham, wfs, log, callback)
#      60     yield ctx
#
# File ~/Documents/Project/GitHub/chem-com/.venv/lib/python3.13/site-packages/gpaw/scf.py:132, in SCFLoop.iterate_eigensolver(self, wfs, ham, dens, log)
#     130     kin_en_using_band = False
#     131 else:
# --> 132     wfs.eigensolver.iterate(ham, wfs)
#     133     e_entropy = wfs.calculate_occupation_numbers(self.fix_fermi_level)
#     134     kin_en_using_band = True
#
# File ~/Documents/Project/GitHub/chem-com/.venv/lib/python3.13/site-packages/gpaw/eigensolvers/eigensolver.py:141, in Eigensolver.iterate(self, ham, wfs)
#     139 if not wfs.orthonormalized:
#     140     wfs.orthonormalize(kpt)
# --> 141 e = self.iterate_one_k_point(ham, wfs, kpt, weights)
#     142 error += e
#     143 if self.orthonormalization_required:
#
# File ~/Documents/Project/GitHub/chem-com/.venv/lib/python3.13/site-packages/ase/utils/timing.py:191, in timer.__call__.<locals>.new_method(slf, *args, **kwargs)
#     188 @functools.wraps(method)
#     189 def new_method(slf, *args, **kwargs):
#     190     slf.timer.start(self.name)
# --> 191     x = method(slf, *args, **kwargs)
#     192     try:
#     193         slf.timer.stop()
#
# File ~/Documents/Project/GitHub/chem-com/.venv/lib/python3.13/site-packages/gpaw/eigensolvers/davidson.py:168, in Davidson.iterate_one_k_point(self, ham, wfs, kpt, weights)
#     164             C_nn[:] = M0.array
#     166 with self.timer('calc. matrices'):
#     167     # <psi2 | H | psi2>
# --> 168     psit2.matrix_elements(
#     169         operator=Ht, result=R, out=M, symmetric=True, cc=True)
#     170     ham.dH(P2, out=P3)
#     171     mmm(1.0, P2, 'N', P3, 'C', 1.0, M)  # , symmetric=True)
#
# File ~/Documents/Project/GitHub/chem-com/.venv/lib/python3.13/site-packages/gpaw/wavefunctions/arrays.py:217, in PlaneWaveExpansionWaveFunctions.matrix_elements(self, other, out, symmetric, cc, operator, result, serial)
#     215 if other is None:
#     216     assert symmetric
# --> 217     operate_and_multiply(self, self.dv, out, operator, result)
#     218 elif not serial:
#     219     assert not symmetric
#
# File ~/Documents/Project/GitHub/chem-com/.venv/lib/python3.13/site-packages/gpaw/wavefunctions/arrays.py:304, in operate_and_multiply(psit1, dv, out, operator, psit2)
#     301         psit2 = psit
#     303 if not (comm.size % 2 == 0 and r == half and comm.rank < half):
# --> 304     m12 = psit2.matrix_elements(psit, symmetric=(r == 0), cc=True,
#     305                                 serial=True)
#     306     n1 = min(((comm.rank - r) % comm.size) * n, N)
#     307     n2 = min(n1 + n, N)
#
# File ~/Documents/Project/GitHub/chem-com/.venv/lib/python3.13/site-packages/gpaw/wavefunctions/arrays.py:223, in PlaneWaveExpansionWaveFunctions.matrix_elements(self, other, out, symmetric, cc, operator, result, serial)
#     220     operate_and_multiply_not_symmetric(self, self.dv, out,
#     221                                        other)
#     222 elif self.dtype == complex:
# --> 223     self.matrix.multiply(self.dv, 'N', other.matrix, 'C',
#     224                          0.0, out, symmetric)
#     225 else:
#     226     self.matrix.multiply(2 * self.dv, 'N', other.matrix, 'T',
#     227                          0.0, out, symmetric)
#
# File ~/Documents/Project/GitHub/chem-com/.venv/lib/python3.13/site-packages/gpaw/matrix.py:168, in Matrix.multiply(self, alpha, opa, b, opb, beta, out, symmetric)
#     165         else:
#     166             return fastmmm2notsym(self, b, out)
# --> 168 dist.multiply(alpha, self, opa, b, opb, beta, out, symmetric)
#     169 return out
#
# File ~/Documents/Project/GitHub/chem-com/.venv/lib/python3.13/site-packages/gpaw/matrix.py:366, in NoDistribution.multiply(self, alpha, a, opa, b, opb, beta, c, symmetric)
#     364         if beta == 1.0 and a.shape[1] == 0:
#     365             return
# --> 366         blas.r2k(0.5 * alpha, a.array, b.array, beta, c.array)
#     367 else:
#     368     blas.mmm(alpha, a.array, opa, b.array, opb, beta, c.array)
#
# File ~/Documents/Project/GitHub/chem-com/.venv/lib/python3.13/site-packages/gpaw/utilities/blas.py:504, in r2k(alpha, a, b, beta, c, trans)
#     501     c *= beta
#     502 if trans == 'c':
#     503     c += (alpha * a.reshape((len(a), -1))
# --> 504           .dot(b.reshape((len(b), -1)).conj().T) +
#     505           alpha * b.reshape((len(b), -1))
#     506           .dot(a.reshape((len(a), -1)).conj().T))
#     507 else:
#     508     c += alpha * (a.conj().T @ b + b.conj().T @ a)
#
# KeyboardInterrupt:

# %%
def analyse_convergence(df: pd.DataFrame, ref_pw: float = 600, ref_k: int = 4) -> pd.DataFrame:
    """Add column with ΔE (meV) vs reference (ref_pw, ref_k) for each surface."""
    rows = []
    for surf in sorted(df["surface"].unique()):
        df_s = df[df["surface"] == surf].copy()
        ref_row = df_s[(df_s["ecut_eV"] == ref_pw) & (df_s["k"] == ref_k)]
        if len(ref_row) != 1:
            print(f"WARNING: reference (ecut={ref_pw}, k={ref_k}) not found for {surf}")
            continue
        E_ref = ref_row["E_eV"].values[0]
        df_s["dE_meV_vs_ref"] = (df_s["E_eV"] - E_ref) * 1000.0
        rows.append(df_s)
    if not rows:
        raise RuntimeError("No reference rows found; adjust ref_pw / ref_k to match your grid.")
    return pd.concat(rows, ignore_index=True)


df_conv_with_delta = analyse_convergence(df_conv, ref_pw=600, ref_k=4)
df_conv_with_delta.sort_values(["surface", "ecut_eV", "k"], inplace=True)
df_conv_with_delta
# Out:
#    surface  ecut_eV   kpts  k        E_eV  dE_meV_vs_ref
# 0    li100      300  2x2x1  2 -131.405546     422.812264
# 1    li100      300  3x3x1  3 -131.740208      88.149978
# 2    li100      300  4x4x1  4 -131.812406      15.951817
# 3    li100      400  2x2x1  2 -131.412825     415.533004
# 4    li100      400  3x3x1  3 -131.747458      80.900470
# 5    li100      400  4x4x1  4 -131.819632       8.725929
# 6    li100      500  2x2x1  2 -131.420321     408.037472
# 7    li100      500  3x3x1  3 -131.754989      73.368632
# 8    li100      500  4x4x1  4 -131.827183       1.174821
# 9    li100      600  2x2x1  2 -131.421458     406.899975
# 10   li100      600  3x3x1  3 -131.756190      72.168005
# 11   li100      600  4x4x1  4 -131.828358       0.000000
# 12   li110      300  2x2x1  2 -128.642857     470.828506
# 13   li110      300  3x3x1  3 -129.051134      62.551547
# 14   li110      300  4x4x1  4 -129.097431      16.253759
# 15   li110      400  2x2x1  2 -128.650326     463.359545
# 16   li110      400  3x3x1  3 -129.058228      55.457559
# 17   li110      400  4x4x1  4 -129.104872       8.813456
# 18   li110      500  2x2x1  2 -128.657966     455.719140
# 19   li110      500  3x3x1  3 -129.066075      47.609882
# 20   li110      500  4x4x1  4 -129.112494       1.191404
# 21   li110      600  2x2x1  2 -128.659149     454.536317
# 22   li110      600  3x3x1  3 -129.067331      46.354370
# 23   li110      600  4x4x1  4 -129.113685       0.000000
# 24   li111      300  2x2x1  2 -125.212861     -89.563069
# 25   li111      300  3x3x1  3 -125.179991     -56.693897
# 26   li111      300  4x4x1  4 -125.108001      15.296893
# 27   li111      400  2x2x1  2 -125.219786     -96.488446
# 28   li111      400  3x3x1  3 -125.186895     -63.597851
# 29   li111      400  4x4x1  4 -125.114935       8.362729
# 30   li111      500  2x2x1  2 -125.226986    -103.688033
# 31   li111      500  3x3x1  3 -125.194037     -70.739264
# 32   li111      500  4x4x1  4 -125.122134       1.163066
# 33   li111      600  2x2x1  2 -125.228146    -104.848099
# 34   li111      600  3x3x1  3 -125.195191     -71.893768
# 35   li111      600  4x4x1  4 -125.123298       0.000000

# %%
# Show a compact table of ΔE (meV) vs (ecut, k) for each surface
from IPython.display import display

for surf in ["li110", "li111", "li100"]:
    print(f"\n=== {surf} ===")
    df_surf = df_conv_with_delta[df_conv_with_delta["surface"] == surf]
    if df_surf.empty:
        print("  (no data for this surface; check state_files / convergence grid)")
        continue
    display(
        df_surf
        .pivot(index="ecut_eV", columns="k", values="dE_meV_vs_ref")
        .rename_axis("ecut_eV (PW)", axis=0)
        .rename_axis("k (k x k x 1)", axis=1)
        .round(3)
    )
# Out:
# === li110 ===
# k (k x k x 1)        2       3       4
# ecut_eV (PW)
# 300            470.829  62.552  16.254
# 400            463.360  55.458   8.813
# 500            455.719  47.610   1.191
# 600            454.536  46.354   0.000
# === li111 ===
# k (k x k x 1)        2       3       4
# ecut_eV (PW)
# 300            -89.563 -56.694  15.297
# 400            -96.488 -63.598   8.363
# 500           -103.688 -70.739   1.163
# 600           -104.848 -71.894   0.000
# === li100 ===
# k (k x k x 1)        2       3       4
# ecut_eV (PW)
# 300            422.812  88.150  15.952
# 400            415.533  80.900   8.726
# 500            408.037  73.369   1.175
# 600            406.900  72.168   0.000
